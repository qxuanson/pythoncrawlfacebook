# %% [markdown]
# # Facebook Data Crawling
# In this notebook, we will be crawling data from Facebook using the Facebook Graph API. We will be using the facebook-scraper

# %% [markdown]
# ## Install the required library
# We will be using the facebook-scraper library to crawl data from Facebook. We will install this library using pip.

# %%
# %pip install facebook_scraper pandas numpy
# Out:
# Requirement already satisfied: facebook_scraper in /home/qxuanson/.local/lib/python3.8/site-packages (0.2.59)
# Requirement already satisfied: pandas in /home/qxuanson/.local/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: numpy in /home/qxuanson/.local/lib/python3.8/site-packages (1.24.4)
# Requirement already satisfied: demjson3<4.0.0,>=3.0.5 in /home/qxuanson/.local/lib/python3.8/site-packages (from facebook_scraper) (3.0.6)
# Requirement already satisfied: dateparser<2.0.0,>=1.0.0 in /home/qxuanson/.local/lib/python3.8/site-packages (from facebook_scraper) (1.1.8)
# Requirement already satisfied: requests-html<0.11.0,>=0.10.0 in /home/qxuanson/.local/lib/python3.8/site-packages (from facebook_scraper) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/qxuanson/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/qxuanson/.local/lib/python3.8/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/qxuanson/.local/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzlocal in /home/qxuanson/.local/lib/python3.8/site-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (5.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /home/qxuanson/.local/lib/python3.8/site-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (2023.10.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.22.0)
# Requirement already satisfied: bs4 in /home/qxuanson/.local/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (0.0.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /home/qxuanson/.local/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.0.2)
# Requirement already satisfied: parse in /home/qxuanson/.local/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.19.1)
# Requirement already satisfied: pyquery in /home/qxuanson/.local/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.0.0)
# Requirement already satisfied: w3lib in /home/qxuanson/.local/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.1.2)
# Requirement already satisfied: fake-useragent in /home/qxuanson/.local/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.14.0)
# Requirement already satisfied: backports.zoneinfo; python_version < "3.9" in /home/qxuanson/.local/lib/python3.8/site-packages (from tzlocal->dateparser<2.0.0,>=1.0.0->facebook_scraper) (0.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/qxuanson/.local/lib/python3.8/site-packages (from bs4->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.12.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/qxuanson/.local/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (6.8.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /home/qxuanson/.local/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /home/qxuanson/.local/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.66.1)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /home/qxuanson/.local/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (8.2.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/lib/python3/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.25.8)
# Requirement already satisfied: websockets<11.0,>=10.0 in /home/qxuanson/.local/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (10.4)
# Requirement already satisfied: certifi>=2021 in /home/qxuanson/.local/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (2023.7.22)
# Requirement already satisfied: cssselect>=1.2.0 in /home/qxuanson/.local/lib/python3.8/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.2.0)
# Requirement already satisfied: lxml>=2.1 in /home/qxuanson/.local/lib/python3.8/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.9.3)
# Requirement already satisfied: importlib-resources>=5.0; python_version < "3.10" in /home/qxuanson/.local/lib/python3.8/site-packages (from fake-useragent->requests-html<0.11.0,>=0.10.0->facebook_scraper) (6.1.0)
# Requirement already satisfied: soupsieve>1.2 in /home/qxuanson/.local/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.5)
# Requirement already satisfied: zipp>=0.5 in /home/qxuanson/.local/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (3.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from facebook_scraper import get_posts
import pandas as pd
import numpy as np

# %% [markdown]
# ## Crawl the data using facebook_scraper
# Now we can get the data from Facebook using the facebook_scraper library. We will be using the get_posts function to get the posts from the fanpage. This function will return a list of dictionaries, where each dictionary represents a post. We will be saving this list of dictionaries to a json file. More information about what you can do with the facebook_scraper library can be found here: https://github.com/kevinzg/facebook-scraper

# %% [markdown]
# ## Define variables
# First we have to define some variables that we will be using throughout the notebook.
# - FANPAGE_LINK: The link to the fanpage that we want to crawl data from. This can be found by going to the fanpage and copying the link from the address bar. For example, the link to the fanpage of the [Nintendo Switch](https://www.facebook.com/NintendoSwitch/) is https://www.facebook.com/NintendoSwitch/. We will be using this link as the value for FANPAGE_LINK.
#
# - COOKIE_PATH: The path to the cookie file that we will be using to authenticate with Facebook. This cookie file can be obtained by logging into Facebook and copying the cookie from the browser. For example, in Chromium, use extension [Get cookies.txt LOCALLY](https://chrome.google.com/webstore/detail/get-cookiestxt/bgaddhkoddajcdgocldbbfleckgcbcid) to get the cookie file. Then save the cookie to a file and use the path to this file as the value for COOKIE_PATH. <span style="color:red; font-weight:bold">USE COOKIE FROM A FAKE ACCOUNT, OTHERWISE YOUR REAL ACCOUNT MIGHT GET BANNED.</span>.
#
#
# - FOLDER_NAME: The name of the folder that we will be saving the data to. This folder will be created in the same directory as this notebook.

# %%
FANPAGE_LINK ="tintucvtv24"
FOLDER_PATH = "Data/"
COOKIE_PATH = "./cookies.txt"

PAGES_NUMBER = 100 # Number of pages to crawl

# %%
post_list = []
for post in get_posts(FANPAGE_LINK,
                    options={"comments": True, "reactions": True, "reactors": False, "allow_extra_requests": True, "posts_per_page": 10},
                    extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH ):
    print(post)
    post_list.append(post)

# %%
post_list

# %% [markdown]
# ## Convert list of dicts to df

# %% [markdown]
# Now we can convert the list of dictionaries to a pandas dataframe. We will be using the pandas library to do this. We will also be saving the dataframe to a xlxs or csv file.

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# To df
path=FOLDER_PATH + FANPAGE_LINK + ".csv"
post_df_full.to_csv(path, index=False)
print(path)

# %%
post_df_full
# Out:
#              post_id                                               text  \
# 0    664681089201099  Việc tập thể dục sẽ làm chúng ta hít thở nhiều...
# 1    664712405864634  ĐT Việt Nam đã rất nỗ lực nhưng ở những giây c...
# 2    877487597381833  🔴 [TRỰC TIẾP] MẤT NGỦ VÀ MỐI LIÊN HỆ VỚI CÁC B...
# 3    664681099201098  Ừ thì túi nilon tiêu thụ có giảm thật nhưng ng...
# 4    664613759207832  Tổng thống Mỹ Biden đón sinh nhật lần thứ 81 b...
# ..               ...                                                ...
# 995  637676341901574  Liên quan đến vụ tai nạn giao thông nghiêm trọ...
# 996  637672528568622  Ngày 2/10, ông Nguyễn Minh Tứ, Phó Chủ tịch Ủy...
# 997  637661555236386  Tối 2/10, bà Phạm Khánh Phong Lan, Trưởng Ban ...
# 998  637431218592753  Những người yêu môi trường họ biết tự lên cho ...
# 999  637431221926086  Sau 3 tháng xảy ra sự cố, kênh Thanh Đa tại TP...
#
#                                              post_text shared_text  \
# 0    Việc tập thể dục sẽ làm chúng ta hít thở nhiều...
# 1    ĐT Việt Nam đã rất nỗ lực nhưng ở những giây c...
# 2    🔴 [TRỰC TIẾP] MẤT NGỦ VÀ MỐI LIÊN HỆ VỚI CÁC B...
# 3    Ừ thì túi nilon tiêu thụ có giảm thật nhưng ng...
